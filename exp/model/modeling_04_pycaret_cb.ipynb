# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from pathlib import Path

from sklearn.model_selection import train_test_split # holdout
from sklearn.inspection import permutation_importance
from sklearn.metrics import matthews_corrcoef, make_scorer
import pycaret
from pycaret.classification import *

# %%
DATA = Path("../../data")

# %%
train_data = pd.read_csv(DATA / "train_missing_value_50per_under.csv")
test_data = pd.read_csv(DATA / "test_missing_value_50per_under.csv")

# %%
train_data
# Out:
#         class  stem-height  stem-width season  cap-diameter  \
# 0           e         4.51       15.39      a          8.80
# 1           p         4.79        6.48      w          4.51
# 2           e         6.85        9.93      w          6.94
# 3           e         4.16        6.53      u          3.88
# 4           e         3.37        8.36      a          5.85
# ...       ...          ...         ...    ...           ...
# 3116940     e        12.14       18.81      u          9.29
# 3116941     e         6.65       26.97      u         10.88
# 3116942     p         9.51       11.06      a          7.82
# 3116943     e         9.13       17.77      u          9.45
# 3116944     p         2.82        7.79      u          3.20
#
#         does-bruise-or-bleed cap-color has-ring stem-color cap-shape habitat  \
# 0                          f         u        f          w         f       d
# 1                          f         o        t          o         x       d
# 2                          f         b        f          n         f       l
# 3                          f         g        f          w         f       d
# 4                          f         w        f          w         x       g
# ...                      ...       ...      ...        ...       ...     ...
# 3116940                    t         n        t          w         f       d
# 3116941                    t         w        f          w         s       d
# 3116942                    f         e        t          y         x       d
# 3116943                    t         n        t          w         p       d
# 3116944                    f         g        f          w         x       g
#
#         gill-color ring-type gill-attachment cap-surface gill-spacing
# 0                w         f               a           s            c
# 1                n         z               a           h            c
# 2                w         f               x           s            c
# 3                g         f               s           y          NaN
# 4                w         f               d           l          NaN
# ...            ...       ...             ...         ...          ...
# 3116940          w         g             NaN         NaN          NaN
# 3116941          p         f               d         NaN            c
# 3116942          w         z               a           e          NaN
# 3116943          p         p               e           i          NaN
# 3116944          w         f               d           s            c
#
# [3116945 rows x 16 columns]

# %%
test_data
# Out:
#          stem-height  stem-width season  cap-diameter does-bruise-or-bleed  \
# 0              11.13       17.12      a          8.64                    t
# 1               1.27       10.75      a          6.90                    f
# 2               6.18        3.14      s          2.00                    f
# 3               4.98        8.51      u          3.47                    f
# 4               6.73       13.70      u          6.17                    f
# ...              ...         ...    ...           ...                  ...
# 2077959         2.67        1.35      u          0.88                    f
# 2077960         2.69        7.38      a          3.12                    f
# 2077961         6.16        9.74      a          5.73                    f
# 2077962         6.00        3.46      a          5.03                    f
# 2077963         2.69       17.71      w         15.51                    f
#
#         cap-color has-ring stem-color cap-shape habitat gill-color ring-type  \
# 0               n        t          w         x       d          w         g
# 1               o        f          n         o       d          y         f
# 2               n        f          n         b       d          n         f
# 3               n        t          w         x       d          n         z
# 4               y        t          y         x       d          y       NaN
# ...           ...      ...        ...       ...     ...        ...       ...
# 2077959         w        f          e         x       d          w         f
# 2077960         w        f          w         x       g          w         f
# 2077961         e        t          y         x       d          w         z
# 2077962         n        f          g         b       d          g         f
# 2077963         w        f          w         f       d          y         f
#
#         gill-attachment cap-surface gill-spacing
# 0                   NaN         NaN          NaN
# 1                   NaN           t            c
# 2                   NaN           g            c
# 3                     s           t            c
# 4                     p           h          NaN
# ...                 ...         ...          ...
# 2077959               a           g            d
# 2077960               d           s            c
# 2077961               a           e          NaN
# 2077962               a           g            d
# 2077963               d         NaN            c
#
# [2077964 rows x 15 columns]

# %%
print(f"Train Shape : {train_data.shape}")
print(f"Test Shape : {test_data.shape}")
# Out:
# Train Shape : (3116945, 16)
# Test Shape : (2077964, 15)

# %%
feature = train_data.iloc[:, 1:]
target = train_data.iloc[:, 0]

# %%
train_X, valid_X, train_y, valid_y = train_test_split(feature, target, test_size=0.1, shuffle=True, stratify=target, random_state=42) # Holdout

# %%
print(f"Train_X Shape : {train_X.shape}")
print(f"Valid_X Shape : {valid_X.shape}")
print(f"Train_y Shape : {train_y.shape}")
print(f"Valid_y Shape : {valid_y.shape}")
# Out:
# Train_X Shape : (2805250, 15)
# Valid_X Shape : (311695, 15)
# Train_y Shape : (2805250,)
# Valid_y Shape : (311695,)

# %%
categorical_features = list(feature.select_dtypes(include=["object"]).columns)
numeric_features = list(feature.select_dtypes(include=["float"]).columns)

# %%
exp_clf = setup(data=train_data, 
                target='class', 
                categorical_features=categorical_features,
                numeric_features=numeric_features,
                session_id=42)
# Out:
# <style type="text/css">
# #T_3df91_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3df91">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3df91_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_3df91_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3df91_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3df91_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_3df91_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_3df91_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3df91_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3df91_row1_col1" class="data row1 col1" >class</td>
#     </tr>
#     <tr>
#       <th id="T_3df91_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3df91_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_3df91_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_3df91_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3df91_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_3df91_row3_col1" class="data row3 col1" >e: 0, p: 1</td>
#     </tr>
#     <tr>
#       <th id="T_3df91_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3df91_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_3df91_row4_col1" class="data row4 col1" >(3116945, 16)</td>
#     </tr>
#     <tr>
#       <th id="T_3df91_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3df91_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_3df91_row5_col1" class="data row5 col1" >(3116945, 61)</td>
#     </tr>
#     <tr>
#       <th id="T_3df91_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3df91_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_3df91_row6_col1" class="data row6 col1" >(2181861, 61)</td>
#     </tr>
#     <tr>
#       <th id="T_3df91_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3df91_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_3df91_row7_col1" class="data row7 col1" >(935084, 61)</td>
#     </tr>
#     <tr>
#       <th id="T_3df91_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3df91_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_3df91_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_3df91_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3df91_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_3df91_row9_col1" class="data row9 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_3df91_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3df91_row10_col0" class="data row10 col0" >Rows with missing values</td>
#       <td id="T_3df91_row10_col1" class="data row10 col1" >62.4%</td>
#     </tr>
#     <tr>
#       <th id="T_3df91_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_3df91_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_3df91_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3df91_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_3df91_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_3df91_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_3df91_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_3df91_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_3df91_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_3df91_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_3df91_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_3df91_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_3df91_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_3df91_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_3df91_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_3df91_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_3df91_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_3df91_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3df91_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_3df91_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_3df91_row17_col1" class="data row17 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_3df91_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_3df91_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_3df91_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_3df91_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_3df91_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_3df91_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_3df91_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_3df91_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_3df91_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3df91_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_3df91_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_3df91_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3df91_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_3df91_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_3df91_row22_col1" class="data row22 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_3df91_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_3df91_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_3df91_row23_col1" class="data row23 col1" >2b77</td>
#     </tr>
#   </tbody>
# </table>

# %%
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# xgboost         Extreme Gradient Boosting
# lightgbm  Light Gradient Boosting Machine
# catboost              CatBoost Classifier
# dummy                    Dummy Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# knn       sklearn.neighbors._classification.KNeighborsCl...   True
# nb                           sklearn.naive_bayes.GaussianNB   True
# dt             sklearn.tree._classes.DecisionTreeClassifier   True
# svm       sklearn.linear_model._stochastic_gradient.SGDC...   True
# rbfsvm                             sklearn.svm._classes.SVC  False
# gpc       sklearn.gaussian_process._gpc.GaussianProcessC...  False
# mlp       sklearn.neural_network._multilayer_perceptron....  False
# ridge           sklearn.linear_model._ridge.RidgeClassifier   True
# rf          sklearn.ensemble._forest.RandomForestClassifier   True
# qda       sklearn.discriminant_analysis.QuadraticDiscrim...   True
# ada       sklearn.ensemble._weight_boosting.AdaBoostClas...   True
# gbc         sklearn.ensemble._gb.GradientBoostingClassifier   True
# lda       sklearn.discriminant_analysis.LinearDiscrimina...   True
# et            sklearn.ensemble._forest.ExtraTreesClassifier   True
# xgboost                       xgboost.sklearn.XGBClassifier   True
# lightgbm                    lightgbm.sklearn.LGBMClassifier   True
# catboost                   catboost.core.CatBoostClassifier   True
# dummy                         sklearn.dummy.DummyClassifier   True

# %%
cb_model = create_model('catboost', fold=10)
# Out:
# <style type="text/css">
# #T_bc723_row10_col0, #T_bc723_row10_col1, #T_bc723_row10_col2, #T_bc723_row10_col3, #T_bc723_row10_col4, #T_bc723_row10_col5, #T_bc723_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_bc723">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc723_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_bc723_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_bc723_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_bc723_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_bc723_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_bc723_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_bc723_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc723_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bc723_row0_col0" class="data row0 col0" >0.9898</td>
#       <td id="T_bc723_row0_col1" class="data row0 col1" >0.9967</td>
#       <td id="T_bc723_row0_col2" class="data row0 col2" >0.9898</td>
#       <td id="T_bc723_row0_col3" class="data row0 col3" >0.9898</td>
#       <td id="T_bc723_row0_col4" class="data row0 col4" >0.9898</td>
#       <td id="T_bc723_row0_col5" class="data row0 col5" >0.9795</td>
#       <td id="T_bc723_row0_col6" class="data row0 col6" >0.9795</td>
#     </tr>
#     <tr>
#       <th id="T_bc723_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bc723_row1_col0" class="data row1 col0" >0.9899</td>
#       <td id="T_bc723_row1_col1" class="data row1 col1" >0.9966</td>
#       <td id="T_bc723_row1_col2" class="data row1 col2" >0.9899</td>
#       <td id="T_bc723_row1_col3" class="data row1 col3" >0.9899</td>
#       <td id="T_bc723_row1_col4" class="data row1 col4" >0.9899</td>
#       <td id="T_bc723_row1_col5" class="data row1 col5" >0.9796</td>
#       <td id="T_bc723_row1_col6" class="data row1 col6" >0.9796</td>
#     </tr>
#     <tr>
#       <th id="T_bc723_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bc723_row2_col0" class="data row2 col0" >0.9893</td>
#       <td id="T_bc723_row2_col1" class="data row2 col1" >0.9963</td>
#       <td id="T_bc723_row2_col2" class="data row2 col2" >0.9893</td>
#       <td id="T_bc723_row2_col3" class="data row2 col3" >0.9893</td>
#       <td id="T_bc723_row2_col4" class="data row2 col4" >0.9893</td>
#       <td id="T_bc723_row2_col5" class="data row2 col5" >0.9784</td>
#       <td id="T_bc723_row2_col6" class="data row2 col6" >0.9784</td>
#     </tr>
#     <tr>
#       <th id="T_bc723_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bc723_row3_col0" class="data row3 col0" >0.9895</td>
#       <td id="T_bc723_row3_col1" class="data row3 col1" >0.9963</td>
#       <td id="T_bc723_row3_col2" class="data row3 col2" >0.9895</td>
#       <td id="T_bc723_row3_col3" class="data row3 col3" >0.9895</td>
#       <td id="T_bc723_row3_col4" class="data row3 col4" >0.9895</td>
#       <td id="T_bc723_row3_col5" class="data row3 col5" >0.9788</td>
#       <td id="T_bc723_row3_col6" class="data row3 col6" >0.9788</td>
#     </tr>
#     <tr>
#       <th id="T_bc723_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bc723_row4_col0" class="data row4 col0" >0.9895</td>
#       <td id="T_bc723_row4_col1" class="data row4 col1" >0.9965</td>
#       <td id="T_bc723_row4_col2" class="data row4 col2" >0.9895</td>
#       <td id="T_bc723_row4_col3" class="data row4 col3" >0.9895</td>
#       <td id="T_bc723_row4_col4" class="data row4 col4" >0.9895</td>
#       <td id="T_bc723_row4_col5" class="data row4 col5" >0.9787</td>
#       <td id="T_bc723_row4_col6" class="data row4 col6" >0.9787</td>
#     </tr>
#     <tr>
#       <th id="T_bc723_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bc723_row5_col0" class="data row5 col0" >0.9900</td>
#       <td id="T_bc723_row5_col1" class="data row5 col1" >0.9967</td>
#       <td id="T_bc723_row5_col2" class="data row5 col2" >0.9900</td>
#       <td id="T_bc723_row5_col3" class="data row5 col3" >0.9900</td>
#       <td id="T_bc723_row5_col4" class="data row5 col4" >0.9900</td>
#       <td id="T_bc723_row5_col5" class="data row5 col5" >0.9799</td>
#       <td id="T_bc723_row5_col6" class="data row5 col6" >0.9799</td>
#     </tr>
#     <tr>
#       <th id="T_bc723_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bc723_row6_col0" class="data row6 col0" >0.9895</td>
#       <td id="T_bc723_row6_col1" class="data row6 col1" >0.9965</td>
#       <td id="T_bc723_row6_col2" class="data row6 col2" >0.9895</td>
#       <td id="T_bc723_row6_col3" class="data row6 col3" >0.9895</td>
#       <td id="T_bc723_row6_col4" class="data row6 col4" >0.9895</td>
#       <td id="T_bc723_row6_col5" class="data row6 col5" >0.9789</td>
#       <td id="T_bc723_row6_col6" class="data row6 col6" >0.9789</td>
#     </tr>
#     <tr>
#       <th id="T_bc723_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_bc723_row7_col0" class="data row7 col0" >0.9898</td>
#       <td id="T_bc723_row7_col1" class="data row7 col1" >0.9966</td>
#       <td id="T_bc723_row7_col2" class="data row7 col2" >0.9898</td>
#       <td id="T_bc723_row7_col3" class="data row7 col3" >0.9898</td>
#       <td id="T_bc723_row7_col4" class="data row7 col4" >0.9898</td>
#       <td id="T_bc723_row7_col5" class="data row7 col5" >0.9795</td>
#       <td id="T_bc723_row7_col6" class="data row7 col6" >0.9795</td>
#     </tr>
#     <tr>
#       <th id="T_bc723_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_bc723_row8_col0" class="data row8 col0" >0.9897</td>
#       <td id="T_bc723_row8_col1" class="data row8 col1" >0.9966</td>
#       <td id="T_bc723_row8_col2" class="data row8 col2" >0.9897</td>
#       <td id="T_bc723_row8_col3" class="data row8 col3" >0.9898</td>
#       <td id="T_bc723_row8_col4" class="data row8 col4" >0.9897</td>
#       <td id="T_bc723_row8_col5" class="data row8 col5" >0.9793</td>
#       <td id="T_bc723_row8_col6" class="data row8 col6" >0.9793</td>
#     </tr>
#     <tr>
#       <th id="T_bc723_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_bc723_row9_col0" class="data row9 col0" >0.9898</td>
#       <td id="T_bc723_row9_col1" class="data row9 col1" >0.9966</td>
#       <td id="T_bc723_row9_col2" class="data row9 col2" >0.9898</td>
#       <td id="T_bc723_row9_col3" class="data row9 col3" >0.9898</td>
#       <td id="T_bc723_row9_col4" class="data row9 col4" >0.9898</td>
#       <td id="T_bc723_row9_col5" class="data row9 col5" >0.9794</td>
#       <td id="T_bc723_row9_col6" class="data row9 col6" >0.9794</td>
#     </tr>
#     <tr>
#       <th id="T_bc723_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_bc723_row10_col0" class="data row10 col0" >0.9897</td>
#       <td id="T_bc723_row10_col1" class="data row10 col1" >0.9966</td>
#       <td id="T_bc723_row10_col2" class="data row10 col2" >0.9897</td>
#       <td id="T_bc723_row10_col3" class="data row10 col3" >0.9897</td>
#       <td id="T_bc723_row10_col4" class="data row10 col4" >0.9897</td>
#       <td id="T_bc723_row10_col5" class="data row10 col5" >0.9792</td>
#       <td id="T_bc723_row10_col6" class="data row10 col6" >0.9792</td>
#     </tr>
#     <tr>
#       <th id="T_bc723_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_bc723_row11_col0" class="data row11 col0" >0.0002</td>
#       <td id="T_bc723_row11_col1" class="data row11 col1" >0.0001</td>
#       <td id="T_bc723_row11_col2" class="data row11 col2" >0.0002</td>
#       <td id="T_bc723_row11_col3" class="data row11 col3" >0.0002</td>
#       <td id="T_bc723_row11_col4

# %%
val_pred_cb = predict_model(cb_model, data=valid_X)

# %%
matthews_corrcoef(valid_y, val_pred_cb["prediction_label"])
# Out:
# 0.9791711854746162

# %%
val_pred_cb["true_label"] = valid_y

# %%
wrong = val_pred_cb[val_pred_cb["prediction_label"]!=val_pred_cb["true_label"]]

# %%
wrong
# Out:
#          stem-height  stem-width season  cap-diameter does-bruise-or-bleed  \
# 681624          8.01    9.600000      a          8.01                    f
# 194748          6.32    5.080000      a          4.65                    f
# 664682          7.15   20.840000      u         10.62                    f
# 1530832         3.55   24.450001      u          5.22                    f
# 291927          8.07    0.000000      a          5.29                    f
# ...              ...         ...    ...           ...                  ...
# 1192977         8.87   17.080000      a         11.05                    t
# 2925388         4.13    5.370000      w          4.76                    f
# 1163365         6.53    6.640000      u          4.06                    f
# 2095732         7.93   16.070000      u          6.80                    t
# 686226          4.39    9.880000      a          6.59                    f
#
#         cap-color has-ring stem-color cap-shape habitat gill-color ring-type  \
# 681624          n        t          w         x       d          w       NaN
# 194748          n        f          n         b       m          p         f
# 664682          n        f          w         x       d          n         f
# 1530832         n        f          n         o       d          f         f
# 291927          w        f          f         o       d          w         f
# ...           ...      ...        ...       ...     ...        ...       ...
# 1192977         w        t          w         f       m          n         l
# 2925388         o        f          o         x       d          n         f
# 1163365         n        f          w         b       d          n         f
# 2095732         y        f          w         x       d          y         f
# 686226          p        f          p         x       d          p         f
#
#         gill-attachment cap-surface gill-spacing prediction_label  \
# 681624              NaN         NaN            c                p
# 194748                x           t            c                p
# 664682                x           s          NaN                e
# 1530832               f         NaN            f                p
# 291927              NaN           s            c                e
# ...                 ...         ...          ...              ...
# 1192977               e           s          NaN                e
# 2925388               a           t          NaN                e
# 1163365             NaN           y            c                p
# 2095732               x           t            c                e
# 686226                s           w          NaN                p
#
#          prediction_score true_label
# 681624             0.6111          e
# 194748             0.9987          e
# 664682             0.9945          p
# 1530832            0.8782          e
# 291927             0.8809          p
# ...                   ...        ...
# 1192977            0.9961          p
# 2925388            0.7140          p
# 1163365            0.5905          e
# 2095732            0.9950          p
# 686226             0.9933          e
#
# [3218 rows x 18 columns]

# %%
def display_number(ax, dtype='float'):
    if dtype == 'float':
        for p in ax.patches:
            ax.text(p.get_x() + (p.get_width()/2),
                    p.get_y() + (p.get_height()*1.015),
                    f"{p.get_height():.2f}",
                    ha = 'center')
    elif dtype == 'int':
        for p in ax.patches:
            ax.text(p.get_x() + (p.get_width()/2),
                    p.get_y() + (p.get_height()*1.015),
                    f"{int(p.get_height())}",
                    ha = 'center')

# %%
plt.figure(figsize=(20, 6))

plt.subplot(1, 3, 1)
ax1 = sns.barplot(data=wrong, x='true_label', y='stem-width')
display_number(ax1)
ax1.set_title("Stem-width")

plt.subplot(1, 3, 2)
ax2 = sns.barplot(data=wrong, x='true_label', y='stem-height')
ax2.set_title("Stem-height")
display_number(ax2)

plt.subplot(1, 3, 3)
ax3 = sns.barplot(data=wrong, x='true_label', y='cap-diameter')
ax3.set_title("Cap-diameter")
display_number(ax3)

# %%
plt.figure(figsize=(25, 6))

plt.subplot(1, 3, 1)
ax4 = sns.countplot(data=wrong, x="season", hue="true_label")
for p in ax4.containers:
    ax4.bar_label(p)

plt.subplot(1, 3, 2)
ax5 = sns.countplot(data=wrong, x="does-bruise-or-bleed", hue='true_label')
for p in ax5.containers:
    ax5.bar_label(p, fmt='%d')

plt.subplot(1, 3, 3)
ax6 = sns.countplot(data=wrong, x="has-ring", hue='true_label')
for p in ax6.containers:
    ax6.bar_label(p, fmt='%d')

# %%
plt.figure(figsize=(25, 14))

plt.subplot(3, 1, 1)
ax7 = sns.countplot(data=wrong, x='gill-color', hue='true_label')
for p in ax7.containers:
    ax7.bar_label(p)

plt.subplot(3, 1, 2)
ax8 = sns.countplot(data=wrong, x='stem-color', hue='true_label')
for p in ax8.containers:
    ax8.bar_label(p)

plt.subplot(3, 1, 3)
ax9 = sns.countplot(data=wrong, x='cap-color', hue='true_label')
for p in ax9.containers:
    ax9.bar_label(p)

# %%
fig = plt.figure(figsize=(28, 20))

ax10 = plt.subplot2grid((4, 3), (0, 0), colspan=4)
sns.countplot(data=wrong, x='habitat', hue='true_label', ax=ax10)
for p in ax10.containers:
    ax10.bar_label(p, fmt="%d")

ax11 = plt.subplot2grid((4, 3), (1, 0), colspan=4)
sns.countplot(data=wrong, x='ring-type', hue='true_label', ax=ax11)
for p in ax11.containers:
    ax11.bar_label(p, fmt="%d")
    
ax12 = plt.subplot2grid((4, 3), (2, 0), colspan=4)
sns.countplot(data=wrong, x='cap-shape', hue='true_label', ax=ax12)
for p in ax12.containers:
    ax12.bar_label(p, fmt="%d")

ax13 = plt.subplot2grid((4, 3), (3, 0))
sns.countplot(data=wrong, x='cap-surface', hue='true_label', ax=ax13)
for p in ax13.containers:
    ax13.bar_label(p, fmt="%d")

ax14 = plt.subplot2grid((4, 3), (3, 1))
sns.countplot(data=wrong, x='gill-spacing', hue='true_label', ax=ax14)
for p in ax14.containers:
    ax14.bar_label(p, fmt="%d")

ax15 = plt.subplot2grid((4, 3), (3, 2))
sns.countplot(data=wrong, x='gill-attachment', hue='true_label', ax=ax15)
for p in ax15.containers:
    ax15.bar_label(p, fmt="%d")

# %%
feature_importance = {}
feature_importance = feature_importance.fromkeys(train_data.columns[1:])
for i, key in enumerate(feature_importance.keys()):
    feature_importance[key] = cb_model.feature_importances_[i]

# %%
feature_importance = sorted(feature_importance.items(), key=lambda x: -x[1])
feature_importance = dict(feature_importance)

# %%
sns.barplot(x=feature_importance.values(), y=feature_importance.keys())
# Out:
# <Axes: >

# %%
test_pred = predict_model(cb_model, data=test_data)

# %%
submission = pd.read_csv(DATA / "sample_submission.csv")

# %%
submission["class"] = test_pred["prediction_label"]

# %%
submission
# Out:
#               id class
# 0        3116945     e
# 1        3116946     p
# 2        3116947     p
# 3        3116948     p
# 4        3116949     e
# ...          ...   ...
# 2077959  5194904     p
# 2077960  5194905     p
# 2077961  5194906     p
# 2077962  5194907     e
# 2077963  5194908     e
#
# [2077964 rows x 2 columns]

# %%
submission.to_csv(DATA / "exp1_missing_value_50per_under.csv", index=False)
